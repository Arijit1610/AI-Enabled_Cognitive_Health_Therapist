# %%
import pandas as pd
encoding = 'ISO-8859-1'
data = pd.read_csv('doctors_data.csv', encoding=encoding)
# print(data)
preferences = ["Anxiety and Stress Management", "Depression and Mood Disorders" , "Anger Management"]
location = ["Kolkata"]
filtereddoc = data[(data['specialty'].isin(preferences)) & (data['location'].isin(location))]
# print(filtereddoc.head())
filtereddoc['score'] = 2
# Out:
# C:\Users\ARIJIT\AppData\Local\Temp\ipykernel_18120\3262612973.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtereddoc['score'] = 2

# %%
filtereddoc.head()
# Out:
#       id   docid                 name                      specialty  \
# 22    23   doc23         Jivika Rajan  Depression and Mood Disorders
# 23    24   doc24            Krish Dar               Anger Management
# 33    34   doc34  Kaira Krishnamurthy  Anxiety and Stress Management
# 114  115  doc115         Lavanya Kaul               Anger Management
# 117  118  doc118           Shayak Dey               Anger Management
#
#      PhoneNumber location  experience_years  patient_reviews  \
# 22    9977941237  Kolkata                32              4.6
# 23    9199654432  Kolkata                10              4.6
# 33    9768567863  Kolkata                14              3.9
# 114   9062804995  Kolkata                33              3.9
# 117   9279533074  Kolkata                21              4.2
#
#                             availability                languages_spoken  \
# 22                ['Thursday', 'Monday']            ['Hindi', 'Bengali']
# 23                ['Thursday', 'Monday']  ['Telugu', 'Hindi', 'Marathi']
# 33   ['Wednesday', 'Thursday', 'Friday']                     ['Bengali']
# 114            ['Wednesday', 'Thursday']  ['Tamil', 'Bengali', 'Telugu']
# 117                          ['Tuesday']                      ['Telugu']
#
#      score
# 22       2
# 23       2
# 33       2
# 114      2
# 117      2

# %%
for index, row in filtereddoc.iterrows():
    if 'Bengali' in row['languages_spoken']:
        filtereddoc.at[index, 'score'] += 1
filtereddoc
# Out:
#       id   docid                 name                      specialty  \
# 22    23   doc23         Jivika Rajan  Depression and Mood Disorders
# 23    24   doc24            Krish Dar               Anger Management
# 33    34   doc34  Kaira Krishnamurthy  Anxiety and Stress Management
# 114  115  doc115         Lavanya Kaul               Anger Management
# 117  118  doc118           Shayak Dey               Anger Management
# 123  124  doc124          Zeeshan Rau               Anger Management
# 150  151  doc151           Kaira Suri               Anger Management
# 151  152  doc152    Jivika Srivastava  Anxiety and Stress Management
# 168  169  doc169        Khushi Kamdar               Anger Management
# 172  173  doc173            Pihu Chad  Anxiety and Stress Management
# 254  255  doc255         Vritika Kala               Anger Management
# 255  256  doc256          Mannat Tata  Depression and Mood Disorders
# 264  265  doc265         Seher Khosla  Depression and Mood Disorders
# 381  382  doc382           Kabir Sant               Anger Management
# 386  387  doc387           Adira Rana               Anger Management
# 412  413  doc413       Parinaaz Badal               Anger Management
# 419  420  doc420            Alia Raju               Anger Management
# 452  453  doc453          Aayush Soni               Anger Management
#
#      PhoneNumber location  experience_years  patient_reviews  \
# 22    9977941237  Kolkata                32              4.6
# 23    9199654432  Kolkata                10              4.6
# 33    9768567863  Kolkata                14              3.9
# 114   9062804995  Kolkata                33              3.9
# 117   9279533074  Kolkata                21              4.2
# 123   9325682089  Kolkata                32              4.1
# 150   9341843199  Kolkata                18              3.6
# 151   9273087056  Kolkata                19              4.3
# 168   9714317961  Kolkata                17              3.9
# 172   9548944028  Kolkata                30              3.9
# 254   9358003410  Kolkata                17              5.0
# 255   9705872435  Kolkata                11              3.8
# 264   9718469133  Kolkata                31              4.1
# 381   9205662048  Kolkata                 9              4.3
# 386   9671574124  Kolkata                12              3.5
# 412   9673241079  Kolkata                27              4.8
# 419   9269672532  Kolkata                33              4.9
# 452   9332119829  Kolkata                 9              4.6
#
#                             availability  \
# 22                ['Thursday', 'Monday']
# 23                ['Thursday', 'Monday']
# 33   ['Wednesday', 'Thursday', 'Friday']
# 114            ['Wednesday', 'Thursday']
# 117                          ['Tuesday']
# 123             ['Tuesday', 'Wednesday']
# 150    ['Monday', 'Friday', 'Wednesday']
# 151                ['Tuesday', 'Friday']
# 168                        ['Wednesday']
# 172                 ['Friday', 'Monday']
# 254    ['Tuesday', 'Thursday', 'Friday']
# 255                           ['Monday']
# 264      ['Monday', 'Friday', 'Tuesday']
# 381                          ['Tuesday']
# 386               ['Friday', 'Thursday']
# 412              ['Wednesday', 'Monday']
# 419                ['Tuesday', 'Friday']
# 452            ['Wednesday', 'Thursday']
#
#                                 languages_spoken  score
# 22                          ['Hindi', 'Bengali']      3
# 23                ['Telugu', 'Hindi', 'Marathi']      2
# 33                                   ['Bengali']      3
# 114               ['Tamil', 'Bengali', 'Telugu']      3
# 117                                   ['Telugu']      2
# 123                        ['Telugu', 'Bengali']      3
# 150                                  ['Bengali']      3
# 151               ['English', 'Tamil', 'Telugu']      2
# 168  ['Telugu', 'Marathi', 'Bengali', 'English']      3
# 172              ['Marathi', 'Hindi', 'Bengali']      3
# 254                                  ['English']      2
# 255              ['English', 'Marathi', 'Hindi']      2
# 264                                  ['Bengali']      3
# 381                 ['Tamil', 'Hindi', 'Telugu']      2
# 386                 ['Tamil', 'Hindi', 'Telugu']      2
# 412              ['Tamil', 'Bengali', 'Marathi']      3
# 419                         ['English', 'Tamil']      2
# 452                       ['Bengali', 'English']      3

# %%
filtereddoc
# Out:
#       id   docid                 name                      specialty  \
# 22    23   doc23         Jivika Rajan  Depression and Mood Disorders
# 33    34   doc34  Kaira Krishnamurthy  Anxiety and Stress Management
# 114  115  doc115         Lavanya Kaul               Anger Management
# 123  124  doc124          Zeeshan Rau               Anger Management
# 150  151  doc151           Kaira Suri               Anger Management
# 168  169  doc169        Khushi Kamdar               Anger Management
# 172  173  doc173            Pihu Chad  Anxiety and Stress Management
# 264  265  doc265         Seher Khosla  Depression and Mood Disorders
# 412  413  doc413       Parinaaz Badal               Anger Management
# 452  453  doc453          Aayush Soni               Anger Management
#
#      PhoneNumber location  experience_years  patient_reviews  \
# 22    9977941237  Kolkata                32              4.6
# 33    9768567863  Kolkata                14              3.9
# 114   9062804995  Kolkata                33              3.9
# 123   9325682089  Kolkata                32              4.1
# 150   9341843199  Kolkata                18              3.6
# 168   9714317961  Kolkata                17              3.9
# 172   9548944028  Kolkata                30              3.9
# 264   9718469133  Kolkata                31              4.1
# 412   9673241079  Kolkata                27              4.8
# 452   9332119829  Kolkata                 9              4.6
#
#                             availability  \
# 22                ['Thursday', 'Monday']
# 33   ['Wednesday', 'Thursday', 'Friday']
# 114            ['Wednesday', 'Thursday']
# 123             ['Tuesday', 'Wednesday']
# 150    ['Monday', 'Friday', 'Wednesday']
# 168                        ['Wednesday']
# 172                 ['Friday', 'Monday']
# 264      ['Monday', 'Friday', 'Tuesday']
# 412              ['Wednesday', 'Monday']
# 452            ['Wednesday', 'Thursday']
#
#                                 languages_spoken  score
# 22                          ['Hindi', 'Bengali']      2
# 33                                   ['Bengali']      2
# 114               ['Tamil', 'Bengali', 'Telugu']      2
# 123                        ['Telugu', 'Bengali']      2
# 150                                  ['Bengali']      2
# 168  ['Telugu', 'Marathi', 'Bengali', 'English']      2
# 172              ['Marathi', 'Hindi', 'Bengali']      2
# 264                                  ['Bengali']      2
# 412              ['Tamil', 'Bengali', 'Marathi']      2
# 452                       ['Bengali', 'English']      2

# %%
from datetime import datetime, timedelta

def get_current_and_next_day():
    # Get the current date
    current_date = datetime.now()
    if current_date.weekday() in [5, 6]:  # Saturday is 5, Sunday is 6
            # If it's Saturday or Sunday, set next day to Monday
            current_date = current_date + timedelta(days=(7 - current_date.weekday()))
    # If it's Friday, set next day to Monday
    if current_date.weekday() == 4:  # Friday is 4
        next_day = current_date + timedelta(days=3)  # 3 days to reach Monday
    else:
        # Calculate the next day
        next_day = current_date + timedelta(days=1)

        # Check if the next day is Saturday or Sunday
        if next_day.weekday() in [5, 6]:  # Saturday is 5, Sunday is 6
            # If it's Saturday or Sunday, set next day to Monday
            next_day = current_date + timedelta(days=(7 - current_date.weekday()))

    # Create a list containing the current day and the next day
    days_list = [current_date.strftime('%A'), next_day.strftime('%A')]

    return days_list

# Call the function
result = get_current_and_next_day()

# Print the result
print(result)
# Out:
# ['Friday', 'Monday']

# %%
result
# Out:
# ['Monday', 'Tuesday']

# %%
for index, row in filtereddoc.iterrows():
    if any(day in row['availability'] for day in result):
        filtereddoc.at[index, 'score'] += 1

# %%
filtereddoc.sort_values(by=['score','experience_years','patient_reviews'], ascending=False)
# Out:
#       id   docid                 name                      specialty  \
# 22    23   doc23         Jivika Rajan  Depression and Mood Disorders
# 264  265  doc265         Seher Khosla  Depression and Mood Disorders
# 172  173  doc173            Pihu Chad  Anxiety and Stress Management
# 412  413  doc413       Parinaaz Badal               Anger Management
# 150  151  doc151           Kaira Suri               Anger Management
# 33    34   doc34  Kaira Krishnamurthy  Anxiety and Stress Management
# 419  420  doc420            Alia Raju               Anger Management
# 114  115  doc115         Lavanya Kaul               Anger Management
# 123  124  doc124          Zeeshan Rau               Anger Management
# 151  152  doc152    Jivika Srivastava  Anxiety and Stress Management
# 254  255  doc255         Vritika Kala               Anger Management
# 168  169  doc169        Khushi Kamdar               Anger Management
# 386  387  doc387           Adira Rana               Anger Management
# 255  256  doc256          Mannat Tata  Depression and Mood Disorders
# 23    24   doc24            Krish Dar               Anger Management
# 452  453  doc453          Aayush Soni               Anger Management
# 117  118  doc118           Shayak Dey               Anger Management
# 381  382  doc382           Kabir Sant               Anger Management
#
#      PhoneNumber location  experience_years  patient_reviews  \
# 22    9977941237  Kolkata                32              4.6
# 264   9718469133  Kolkata                31              4.1
# 172   9548944028  Kolkata                30              3.9
# 412   9673241079  Kolkata                27              4.8
# 150   9341843199  Kolkata                18              3.6
# 33    9768567863  Kolkata                14              3.9
# 419   9269672532  Kolkata                33              4.9
# 114   9062804995  Kolkata                33              3.9
# 123   9325682089  Kolkata                32              4.1
# 151   9273087056  Kolkata                19              4.3
# 254   9358003410  Kolkata                17              5.0
# 168   9714317961  Kolkata                17              3.9
# 386   9671574124  Kolkata                12              3.5
# 255   9705872435  Kolkata                11              3.8
# 23    9199654432  Kolkata                10              4.6
# 452   9332119829  Kolkata                 9              4.6
# 117   9279533074  Kolkata                21              4.2
# 381   9205662048  Kolkata                 9              4.3
#
#                             availability  \
# 22                ['Thursday', 'Monday']
# 264      ['Monday', 'Friday', 'Tuesday']
# 172                 ['Friday', 'Monday']
# 412              ['Wednesday', 'Monday']
# 150    ['Monday', 'Friday', 'Wednesday']
# 33   ['Wednesday', 'Thursday', 'Friday']
# 419                ['Tuesday', 'Friday']
# 114            ['Wednesday', 'Thursday']
# 123             ['Tuesday', 'Wednesday']
# 151                ['Tuesday', 'Friday']
# 254    ['Tuesday', 'Thursday', 'Friday']
# 168                        ['Wednesday']
# 386               ['Friday', 'Thursday']
# 255                           ['Monday']
# 23                ['Thursday', 'Monday']
# 452            ['Wednesday', 'Thursday']
# 117                          ['Tuesday']
# 381                          ['Tuesday']
#
#                                 languages_spoken  score
# 22                          ['Hindi', 'Bengali']      4
# 264                                  ['Bengali']      4
# 172              ['Marathi', 'Hindi', 'Bengali']      4
# 412              ['Tamil', 'Bengali', 'Marathi']      4
# 150                                  ['Bengali']      4
# 33                                   ['Bengali']      4
# 419                         ['English', 'Tamil']      3
# 114               ['Tamil', 'Bengali', 'Telugu']      3
# 123                        ['Telugu', 'Bengali']      3
# 151               ['English', 'Tamil', 'Telugu']      3
# 254                                  ['English']      3
# 168  ['Telugu', 'Marathi', 'Bengali', 'English']      3
# 386                 ['Tamil', 'Hindi', 'Telugu']      3
# 255              ['English', 'Marathi', 'Hindi']      3
# 23                ['Telugu', 'Hindi', 'Marathi']      3
# 452                       ['Bengali', 'English']      3
# 117                                   ['Telugu']      2
# 381                 ['Tamil', 'Hindi', 'Telugu']      2
